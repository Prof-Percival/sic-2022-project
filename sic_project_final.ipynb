# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

#                                        CRIMES CATEGORIES

contact_crimes = ['Murder', 'Sexual Offences', 'Attempted murder', 'Assault with the intent to inflict grievous bodily harm',
                  'Common assault', 'Common robbery', 'Robbery with aggravating circumstances']

sexual_offences = ['Rape', 'Sexual Assault', 'Attempted Sexual Offences', 'Contact Sexual Offences']

aggravated_robbery = ['Carjacking', 'Robbery at residential premises', 'Robbery at non-residential premises',
                     'Robbery of cash in transit', 'Bank robbery', 'Truck hijacking']

contact_related_crimes = ['Arson', 'Malicious damage to property']

property_related_crimes = ['Burglary at non-residential premises', 'Burglary at residential premises',
                          'Theft of motor vehicle and motorcycle', 'Theft out of or from motor vehicle', 'Stock-theft']

other_serious_crimes = ['All theft not mentioned elsewhere', 'Commercial crime', 'Shoplifting']

crime_detected_by_police = ['Illegal possession of firearms and ammunition', 'Drug-related crime',
                           'Driving under the influence of alcohol or drugs', 'Sexual Offences detected as a result of police action']

# %%
# Read CSV File (Crime Statistics)
crime_stats = pd.read_csv('./Data/Crime/Crime-Stats-2017-to-2022.csv')
#crime_stats.set_index('Category', inplace=True)
crime_stats.head()
# Out:
#                                             Category  2017-2018  2018-2019  \
# 0                                             Murder       4859       4668
# 1                                    Sexual Offences      11526      11387
# 2                                   Attempted murder       4492       4429
# 3  Assault with the intent to inflict grievous bo...      37336      37564
# 4                                     Common assault      35727      36024
#
#    2019-2020  2020-2021  2021-2022
# 0       5398       3466       5760
# 1      12094       7296      12702
# 2       4575       3487       5145
# 3      37425      22064      37530
# 4      36185      25995      39406

# %%
print('\t\t\t\t\t\tCONTACT CRIMES')
for crime in contact_crimes:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						CONTACT CRIMES

# %%
print('\t\t\t\t\t\tSEXUAL OFFENCES')
for crime in sexual_offences:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						SEXUAL OFFENCES

# %%
print('\t\t\t\t\t\tAGGRAVATED ROBBERY')
for crime in aggravated_robbery:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						AGGRAVATED ROBBERY

# %%
print('\t\t\t\t\t\tCONTACT RELATED CRIMES')
for crime in contact_related_crimes:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						CONTACT RELATED CRIMES

# %%
print('\t\t\t\t\t\tPROPERTY RELATED CRIMES')
for crime in property_related_crimes:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						PROPERTY RELATED CRIMES

# %%
print('\t\t\t\t\t\tOTHER SERIOUS CRIMES')
for crime in other_serious_crimes:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						OTHER SERIOUS CRIMES

# %%
print('\t\t\t\t\t\tCRIME DETECTED AS A RESULT OF POLICE ACTION')
for crime in crime_detected_by_police:
    category = 'Category: ' + crime
    data_to_plot = crime_stats.loc[crime_stats['Category'] == crime]
    plt.figure(figsize=(10,4)) # this creates a figure 14 inch wide, 8 inch high
    ax = sns.barplot(data=data_to_plot)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right",fontsize=12,)
    ax.set_title(category,fontsize=20)
    ax.set_ylabel('Number of Crimes Reported',fontsize=14)
    ax.set_xlabel('Years (2017 - 2022)',fontsize=14)
# Out:
# 						CRIME DETECTED AS A RESULT OF POLICE ACTION

# %%
crime_stats['Total 2017-2022'] = crime_stats.sum(axis=1, numeric_only=True)
crime_stats = crime_stats.sort_values('Total 2017-2022', ascending = False)

# Plot Figure
plt.figure(figsize=(14,10)) # this creates a figure 14 inch wide, 10 inch high
ax = sns.barplot(data=crime_stats,y='Category',x='Total 2017-2022',palette='coolwarm')
ax.set_title('Total Crimes Reported by Category (2017-2022)',fontsize=16)
ax.set_ylabel('Type of Crime',fontsize=14)
ax.set_xlabel('Number of Crimes Reported',fontsize=14)
# Out:
# Text(0.5, 0, 'Number of Crimes Reported')

# %%
f,ax = plt.subplots(figsize=(10, 8))
ax.set_title('Correlation Heatmap',fontsize=16)
corr = crime_stats.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# <AxesSubplot: title={'center': 'Correlation Heatmap'}>

# %%
corr.style.format(precision = 2).background_gradient()  # Set precision to 2 decimals
# Out:
# <style type="text/css">
# #T_5e154_row0_col0, #T_5e154_row1_col1, #T_5e154_row2_col2, #T_5e154_row3_col3, #T_5e154_row4_col4, #T_5e154_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5e154_row0_col1 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_5e154_row0_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_5e154_row0_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_5e154_row0_col4, #T_5e154_row1_col2, #T_5e154_row1_col3, #T_5e154_row3_col0, #T_5e154_row3_col1, #T_5e154_row3_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5e154_row0_col5 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_5e154_row1_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_5e154_row1_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_5e154_row1_col5 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_5e154_row2_col0 {
#   background-color: #509ac6;
# ...

# %%
crime_stats.describe()
# Out:
#           2017-2018     2018-2019     2019-2020     2020-2021     2021-2022  \
# count     31.000000     31.000000     31.000000     31.000000     31.000000
# mean   16943.193548  17170.129032  16028.419355   9971.774194  14048.032258
# std    21025.340651  20803.491617  17817.769407  11507.542604  15290.411286
# min        4.000000      1.000000      0.000000      0.000000      1.000000
# 25%     2165.000000   2795.500000   2881.000000   1873.500000   2523.500000
# 50%     7217.000000   9018.000000   9737.000000   5564.000000   9433.000000
# 75%    24488.000000  24323.500000  24038.500000  18045.500000  22670.000000
# max    75313.000000  76400.000000  71704.000000  45455.000000  60056.000000
#
#        Total 2017-2022
# count        31.000000
# mean      74161.548387
# std       84637.619675
# min           6.000000
# 25%       12634.000000
# 50%       41830.000000
# 75%      112631.500000
# max      326781.000000
